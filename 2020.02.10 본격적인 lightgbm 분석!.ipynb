# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import gc
from sklearn.preprocessing import LabelEncoder
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import lightgbm as lgb
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
# %matplotlib inline

# !pip install xgboost
import xgboost as xgb
# Out:
# Requirement already satisfied: xgboost in c:\programdata\anaconda3\lib\site-packages (0.90)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from xgboost) (1.3.1)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from xgboost) (1.16.5)

# %%
df = pd.read_csv('.csv')
df_test = pd.read_csv('test.csv')

print(df.shape)
# Out:
# (15031, 37)

# %%
# 가격과 가장 상관관계가 높은 순서대로 스피어만 순위 상관관계 나타냄(히트맵)

import scipy as sp

#abs는 절댓값 함수! 이는 반비례 관계(마이너스)도 고려하기 위함. 
cor_abs = abs(df.corr(method='spearman'))

# price와 상관관계가 높은 column 10개 뽑기
# nlargest : 컬렉션 내부에서 가장 큰 n개의 아이템 찾으려 할 때
# .index : index 값 추출
cor_cols = cor_abs.nlargest(n=10, columns='price').index

#spearman coefficient matrix
#.values : 딕셔너리 value 값을 보여줌
cor = np.array(sp.stats.spearmanr(df[cor_cols].values))[0] #상관계수 추출

#상관계수 히트맵 그리기
plt.figure( figsize = (10,10))
sns.set( font_scale=1.25)
#annot = True : 숫자 표시, annot_kws : 숫자 크기
sns.heatmap(cor, fmt='.2f', annot=True, annot_kws={'size':10}, 
           xticklabels=cor_cols.values, yticklabels=cor_cols.values)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\shape_base.py in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     376     try:
# --> 377         ind0 = next(inds)
#     378     except StopIteration:
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-d7cabf30c1a7> in <module>
#      13 #spearman coefficient matrix
#      14 #.values : 딕셔너리 value 값을 보여줌
# ---> 15 cor = np.array(sp.stats.spearmanr(df[cor_cols].values))[0] #상관계수 추출
#      16
#      17 #상관계수 히트맵 그리기
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py in spearmanr(a, b, axis, nan_policy)
#    3741                 variable_has_nan = np.isnan(a).sum(axis=axisout)
#    3742
# -> 3743     a_ranked = np.apply_along_axis(rankdata, axisout, a)
#    3744     rs = np.corrcoef(a_ranked, rowvar=axisout)
#    3745     dof = n_obs - 2  # degrees of freedom
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\shape_base.py in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     377         ind0 = next(inds)
#     378     except StopIteration:
# --> 379         raise ValueError('Cannot apply_along_axis when any iteration dimensions are 0')
#     380     res = asanyarray(func1d(inarr_view[ind0], *args, **kwargs))
#     381
#
# ValueError: Cannot apply_along_axis when any iteration dimensions are 0

# %%
df_test.head()
# Out:
#       id      date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  15035  20141209         3       2.25         2570      7242     2.0
# 1  15036  20141209         4       3.00         1960      5000     1.0
# 2  15037  20140512         4       4.50         5420    101930     1.0
# 3  15038  20150415         3       1.00         1780      7470     1.0
# 4  15039  20150312         3       2.50         1890      6560     2.0
#
#    waterfront  view  condition  ...  yr_built  yr_renovated  zipcode      lat  \
# 0           0     0          3  ...      1951          1991    98125  47.7210
# 1           0     0          5  ...      1965          1965    98136  47.5208
# 2           0     0          3  ...      2001          2001    98053  47.6561
# 3           0     0          3  ...      1960          1960    98146  47.5123
# 4           0     0          3  ...      2003          2003    98038  47.3684
#
#       long  sqft_living15  sqft_lot15  totla_rooms  is_renovated  \
# 0 -122.319           1690        7639         5.25             1
# 1 -122.393           1360        5000         7.00             0
# 2 -122.005           4760      101930         8.50             0
# 3 -122.337           1780        8113         4.00             0
# 4 -122.031           2390        7570         5.50             0
#
#    living_ratio(lot)
# 0           0.354874
# 1           0.392000
# 2           0.053174
# 3           0.238286
# 4           0.288110
#
# [5 rows x 23 columns]

# %% [markdown]
# # How to use lat / long in house price

# %%
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import LabelEncoder, StandardScaler, RobustScaler
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

import xgboost as xgb
import lightgbm as lgb

# plot 의 defaults 를 지정해준다. 
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12,8) #그림 사이즈
plt.rcParams['font.size'] = 12 #글씨 크기

#pandas가 어디까지 보여줄 것인가?
pd.options.display.max_rows = 10000
pd.options.display.max_columns = 10000
pd.options.display.max_colwidth = 1000

# %%
#난수 생성 (using Numpy) : 난수 시작 숫자(seed)를 정해주면 컴퓨터는 정해진 알고리즘에 따라
#난수처럼 보이는 수열을 생성한다. (seed를 지정하면 항상 같은 숫자가 나타난다)

random_seed = 42 

np.random.seed(random_seed)

# %% [markdown]
# ## Baseline Model :   LightGBM
# (5-Fold out of fold prediction)
# **categorical data : One Hot incoding 처리**

# %%
# Baseline model 의 CV 스코어

# df 데이터를 train/ test 데이터로 나누기
from sklearn.model_selection import train_test_split

train_data = df.drop(['price'], axis=1)
target_data = df['price']
x_train, x_valid, y_train, y_valid = train_test_split(train_data, target_data, random_state=1, test_size=0.2)
x_test = df_test


print(train_data.shape, x_test.shape)
# Out:
# (15031, 24) (6468, 23)

# %%
df_test.head()
# Out:
#       id      date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  15035  20141209         3       2.25         2570      7242     2.0
# 1  15036  20141209         4       3.00         1960      5000     1.0
# 2  15037  20140512         4       4.50         5420    101930     1.0
# 3  15038  20150415         3       1.00         1780      7470     1.0
# 4  15039  20150312         3       2.50         1890      6560     2.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        2170            400      1951
# 1           0     0          5      7        1050            910      1965
# 2           0     0          3     11        3890           1530      2001
# 3           0     0          3      7        1050            730      1960
# 4           0     0          3      7        1890              0      2003
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# 0          1991    98125  47.7210 -122.319           1690        7639
# 1          1965    98136  47.5208 -122.393           1360        5000
# 2          2001    98053  47.6561 -122.005           4760      101930
# 3          1960    98146  47.5123 -122.337           1780        8113
# 4          2003    98038  47.3684 -122.031           2390        7570
#
#    totla_rooms  is_renovated  living_ratio(lot)
# 0         5.25             1           0.354874
# 1         7.00             0           0.392000
# 2         8.50             0           0.053174
# 3         4.00             0           0.238286
# 4         5.50             0           0.288110

# %%
# lgb_param 입력 (하이퍼파라미터 튜닝)

import lightgbm as lgb

train_ds = lgb.Dataset(x_train, label = y_train)
test_ds = lgb.Dataset(x_valid, label = y_valid)

params = {
    'objective': 'regression', #method
    'learning_rate': 0.05, #학습률
    'num_leaves': 15,  #하나의 트리가 가질 수 있는 최대 리프 개수
    'bagging_fraction': 0.7, #배깅 사용
    'bagging_freq': 1,
    'feature_fraction': 0.7, #트리를 학습할 때마다 선택하는 feature의 비율
    'seed': random_seed, 
    'metric': ['rmse'], #평가 지표
}

model = lgb.train(params, train_ds, 1000, test_ds, early_stopping_rounds=100)
# Out:
# [1]	valid_0's rmse: 0.519277
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's rmse: 0.500567
# [3]	valid_0's rmse: 0.486476
# [4]	valid_0's rmse: 0.472733
# [5]	valid_0's rmse: 0.460336
# [6]	valid_0's rmse: 0.445143
# [7]	valid_0's rmse: 0.430836
# [8]	valid_0's rmse: 0.417236
# [9]	valid_0's rmse: 0.40427
# [10]	valid_0's rmse: 0.392076
# [11]	valid_0's rmse: 0.380773
# [12]	valid_0's rmse: 0.369949
# [13]	valid_0's rmse: 0.359715
# [14]	valid_0's rmse: 0.350283
# [15]	valid_0's rmse: 0.341474
# [16]	valid_0's rmse: 0.333067
# [17]	valid_0's rmse: 0.325173
# [18]	valid_0's rmse: 0.318898
# [19]	valid_0's rmse: 0.31293
# [20]	valid_0's rmse: 0.306462
# [21]	valid_0's rmse: 0.299658
# [22]	valid_0's rmse: 0.293439
# [23]	valid_0's rmse: 0.287572
# [24]	valid_0's rmse: 0.283115
# [25]	valid_0's rmse: 0.278764
# [26]	valid_0's rmse: 0.273896
# [27]	valid_0's rmse: 0.269085
# [28]	valid_0's rmse: 0.26478
# [29]	valid_0's rmse: 0.260513
# [30]	valid_0's rmse: 0.256843
# [31]	valid_0's rmse: 0.252895
# [32]	valid_0's rmse: 0.250012
# [33]	valid_0's rmse: 0.246569
# [34]	valid_0's rmse: 0.243561
# [35]	valid_0's rmse: 0.240552
# [36]	valid_0's rmse: 0.237461
# [37]	valid_0's rmse: 0.234535
# [38]	valid_0's rmse: 0.232256
# [39]	valid_0's rmse: 0.229443
# [40]	valid_0's rmse: 0.227342
# [41]	valid_0's rmse: 0.22528
# [42]	valid_0's rmse: 0.223693
# [43]	valid_0's rmse: 0.22153
# [44]	valid_0's rmse: 0.219753
# [45]	valid_0's rmse: 0.2177
# [46]	valid_0's rmse: 0.216369
# [47]	valid_0's rmse: 0.21491
# [48]	valid_0's rmse: 0.212957
# [49]	valid_0's rmse: 0.21175
# [50]	valid_0's rmse: 0.210189
# [51]	valid_0's rmse: 0.208872
# [52]	valid_0's rmse: 0.208018
# [53]	valid_0's rmse: 0.206852
# [54]	valid_0's rmse: 0.205929
# [55]	valid_0's rmse: 0.204516
# [56]	valid_0's rmse: 0.203432
# [57]	valid_0's rmse: 0.201982
# [58]	valid_0's rmse: 0.201134
# [59]	valid_0's rmse: 0.200391
# [60]	valid_0's rmse: 0.199247
# [61]	valid_0's rmse: 0.198455
# [62]	valid_0's rmse: 0.197828
# [63]	valid_0's rmse: 0.197204
# [64]	valid_0's rmse: 0.196665
# [65]	valid_0's rmse: 0.19613
# [66]	valid_0's rmse: 0.19551
# [67]	valid_0's rmse: 0.194765
# [68]	valid_0's rmse: 0.193953
# [69]	valid_0's rmse: 0.193044
# [70]	valid_0's rmse: 0.192441
# [71]	valid_0's rmse: 0.191881
# [72]	valid_0's rmse: 0.19114
# [73]	valid_0's rmse: 0.190436
# [74]	valid_0's rmse: 0.189966
# [75]	valid_0's rmse: 0.189462
# [76]	valid_0's rmse: 0.188787
# [77]	valid_0's rmse: 0.188442
# [78]	valid_0's rmse: 0.187925
# [79]	valid_0's rmse: 0.187408
# [80]	valid_0's rmse: 0.187009
# [81]	valid_0's rmse: 0.18674
# [82]	valid_0's rmse: 0.186285
# [83]	valid_0's rmse: 0.185986
# [84]	valid_0's rmse: 0.18555
# [85]	valid_0's rmse: 0.185224
# [86]	valid_0's rmse: 0.184931
# [87]	valid_0's rmse: 0.184506
# [88]	valid_0's rmse: 0.184167
# [89]	valid_0's rmse: 0.183882
# [90]	valid_0's rmse: 0.183396
# [91]	valid_0's rmse: 0.183115
# [92]	valid_0's rmse: 0.182702
# [93]	valid_0's rmse: 0.182393
# [94]	valid_0's rmse: 0.181929
# [95]	valid_0's rmse: 0.181653
# [96]	valid_0's rmse: 0.181545
# [97]	valid_0's rmse: 0.181291
# [98]	valid_0's rmse: 0.180851
# [99]	valid_0's rmse: 0.18065
# [100]	valid_0's rmse: 0.180502
# [101]	valid_0's rmse: 0.180272
# [102]	valid_0's rmse: 0.180111
# [103]	valid_0's rmse: 0.179872
# [104]	valid_0's rmse: 0.179646
# [105]	valid_0's rmse: 0.179459
# [106]	valid_0's rmse: 0.179305
# [107]	valid_0's rmse: 0.179001
# [108]	valid_0's rmse: 0.178858
# [109]	valid_0's rmse: 0.178495
# [110]	valid_0's rmse: 0.178191
# [111]	valid_0's rmse: 0.178066
# [112]	valid_0's rmse: 0.177901
# [113]	valid_0's rmse: 0.177803
# [114]	valid_0's rmse: 0.177711
# [115]	valid_0's rmse: 0.177469
# [116]	valid_0's rmse: 0.177383
# [117]	valid_0's rmse: 0.177228
# [118]	valid_0's rmse: 0.177219
# [119]	valid_0's rmse: 0.176994
# [120]	valid_0's rmse: 0.176912
# [121]	valid_0's rmse: 0.176764
# [122]	valid_0's rmse: 0.176709
# [123]	valid_0's rmse: 0.176421
# [124]	valid_0's rmse: 0.176245
# [125]	valid_0's rmse: 0.176153
# [126]	valid_0's rmse: 0.176071
# [127]	valid_0's rmse: 0.175815
# [128]	valid_0's rmse: 0.175636
# [129]	valid_0's rmse: 0.175423
# [130]	valid_0's rmse: 0.17534
# [131]	valid_0's rmse: 0.175153
# [132]	valid_0's rmse: 0.174994
# [133]	valid_0's rmse: 0.174846
# [134]	valid_0's rmse: 0.17482
# [135]	valid_0's rmse: 0.174698
# [136]	valid_0's rmse: 0.174557
# [137]	valid_0's rmse: 0.174352
# [138]	valid_0's rmse: 0.174309
# [139]	valid_0's rmse: 0.174258
# [140]	valid_0's rmse: 0.173946
# [141]	valid_0's rmse: 0.173887
# [142]	valid_0's rmse: 0.173781
# [143]	valid_0's rmse: 0.173671
# [144]	valid_0's rmse: 0.173594
# [145]	valid_0's rmse: 0.173538
# [146]	valid_0's rmse: 0.173389
# [147]	valid_0's rmse: 0.173315
# [148]	valid_0's rmse: 0.173263
# [149]	valid_0's rmse: 0.173023
# [150]	valid_0's rmse: 0.172813
# [151]	valid_0's rmse: 0.172776
# [152]	valid_0's rmse: 0.172628
# [153]	valid_0's rmse: 0.172531
# [154]	valid_0's rmse: 0.17233
# [155]	valid_0's rmse: 0.172227
# [156]	valid_0's rmse: 0.171988
# [157]	valid_0's rmse: 0.171918
# [158]	valid_0's rmse: 0.17183
# [159]	valid_0's rmse: 0.171781
# [160]	valid_0's rmse: 0.171661
# [161]	valid_0's rmse: 0.171498
# [162]	valid_0's rmse: 0.171442
# [163]	valid_0's rmse: 0.171389
# [164]	valid_0's rmse: 0.171266
# [165]	valid_0's rmse: 0.171209
# [166]	valid_0's rmse: 0.171135
# [167]	valid_0's rmse: 0.171014
# [168]	valid_0's rmse: 0.170949
# [169]	valid_0's rmse: 0.170736
# [170]	valid_0's rmse: 0.170692
# [171]	valid_0's rmse: 0.170647
# [172]	valid_0's rmse: 0.170582
# [173]	valid_0's rmse: 0.170454
# [174]	valid_0's rmse: 0.170391
# [175]	valid_0's rmse: 0.170341
# [176]	valid_0's rmse: 0.170194
# [177]	valid_0's rmse: 0.170125
# [178]	valid_0's rmse: 0.170016
# [179]	valid_0's rmse: 0.169874
# [180]	valid_0's rmse: 0.16979
# [181]	valid_0's rmse: 0.169713
# [182]	valid_0's rmse: 0.169571
# [183]	valid_0's rmse: 0.169474
# [184]	valid_0's rmse: 0.169436
# [185]	valid_0's rmse: 0.169373
# [186]	valid_0's rmse: 0.169267
# [187]	valid_0's rmse: 0.169193
# [188]	valid_0's rmse: 0.169189
# [189]	valid_0's rmse: 0.169181
# [190]	valid_0's rmse: 0.169111
# [191]	valid_0's rmse: 0.169094
# [192]	valid_0's rmse: 0.168893
# [193]	valid_0's rmse: 0.168814
# [194]	valid_0's rmse: 0.168757
# [195]	valid_0's rmse: 0.168681
# [196]	valid_0's rmse: 0.168567
# [197]	valid_0's rmse: 0.168517
# [198]	valid_0's rmse: 0.16834
# [199]	valid_0's rmse: 0.168224
# [200]	valid_0's rmse: 0.168224
# [201]	valid_0's rmse: 0.168156
# [202]	valid_0's rmse: 0.168023
# [203]	valid_0's rmse: 0.167957
# [204]	valid_0's rmse: 0.167894
# [205]	valid_0's rmse: 0.167838
# [206]	valid_0's rmse: 0.167789
# [207]	valid_0's rmse: 0.167784
# [208]	valid_0's rmse: 0.16767
# [209]	valid_0's rmse: 0.167643
# [210]	valid_0's rmse: 0.167612
# [211]	valid_0's rmse: 0.167569
# [212]	valid_0's rmse: 0.167447
# [213]	valid_0's rmse: 0.167368
# [214]	valid_0's rmse: 0.167275
# [215]	valid_0's rmse: 0.167235
# [216]	valid_0's rmse: 0.167202
# [217]	valid_0's rmse: 0.167134
# [218]	valid_0's rmse: 0.167181
# [219]	valid_0's rmse: 0.167183
# [220]	valid_0's rmse: 0.167018
# [221]	valid_0's rmse: 0.166922
# [222]	valid_0's rmse: 0.166815
# [223]	valid_0's rmse: 0.166657
# [224]	valid_0's rmse: 0.166641
# [225]	valid_0's rmse: 0.166671
# [226]	valid_0's rmse: 0.166645
# [227]	valid_0's rmse: 0.16654
# [228]	valid_0's rmse: 0.166482
# [229]	valid_0's rmse: 0.166386
# [230]	valid_0's rmse: 0.166398
# [231]	valid_0's rmse: 0.166307
# [232]	valid_0's rmse: 0.166285
# [233]	valid_0's rmse: 0.166149
# [234]	valid_0's rmse: 0.166142
# [235]	valid_0's rmse: 0.166038
# [236]	valid_0's rmse: 0.165871
# [237]	valid_0's rmse: 0.16588
# [238]	valid_0's rmse: 0.165835
# [239]	valid_0's rmse: 0.165788
# [240]	valid_0's rmse: 0.165652
# [241]	valid_0's rmse: 0.165516
# [242]	valid_0's rmse: 0.165447
# [243]	valid_0's rmse: 0.165259
# [244]	valid_0's rmse: 0.165244
# [245]	valid_0's rmse: 0.165124
# [246]	valid_0's rmse: 0.165094
# [247]	valid_0's rmse: 0.165018
# [248]	valid_0's rmse: 0.164964
# [249]	valid_0's rmse: 0.164925
# [250]	valid_0's rmse: 0.164911
# [251]	valid_0's rmse: 0.164752
# [252]	valid_0's rmse: 0.164729
# [253]	valid_0's rmse: 0.164648
# [254]	valid_0's rmse: 0.164532
# [255]	valid_0's rmse: 0.164474
# [256]	valid_0's rmse: 0.1644
# [257]	valid_0's rmse: 0.164347
# [258]	valid_0's rmse: 0.164226
# [259]	valid_0's rmse: 0.164117
# [260]	valid_0's rmse: 0.163946
# [261]	valid_0's rmse: 0.163929
# [262]	valid_0's rmse: 0.163914
# [263]	valid_0's rmse: 0.163831
# [264]	valid_0's rmse: 0.163779
# [265]	valid_0's rmse: 0.163719
# [266]	valid_0's rmse: 0.163602
# [267]	valid_0's rmse: 0.163573
# [268]	valid_0's rmse: 0.163575
# [269]	valid_0's rmse: 0.163544
# [270]	valid_0's rmse: 0.163554
# [271]	valid_0's rmse: 0.163542
# [272]	valid_0's rmse: 0.163399
# [273]	valid_0's rmse: 0.163395
# [274]	valid_0's rmse: 0.163365
# [275]	valid_0's rmse: 0.163323
# [276]	valid_0's rmse: 0.163287
# [277]	valid_0's rmse: 0.163147
# [278]	valid_0's rmse: 0.163047
# [279]	valid_0's rmse: 0.163003
# [280]	valid_0's rmse: 0.162973
# [281]	valid_0's rmse: 0.162945
# [282]	valid_0's rmse: 0.162958
# [283]	valid_0's rmse: 0.162886
# [284]	valid_0's rmse: 0.162807
# [285]	valid_0's rmse: 0.162766
# [286]	valid_0's rmse: 0.162672
# [287]	valid_0's rmse: 0.162636
# [288]	valid_0's rmse: 0.162489
# [289]	valid_0's rmse: 0.1624
# [290]	valid_0's rmse: 0.162235
# [291]	valid_0's rmse: 0.162144
# [292]	valid_0's rmse: 0.162139
# [293]	valid_0's rmse: 0.162135
# [294]	valid_0's rmse: 0.162116
# [295]	valid_0's rmse: 0.162017
# [296]	valid_0's rmse: 0.162008
# [297]	valid_0's rmse: 0.161919
# [298]	valid_0's rmse: 0.161782
# [299]	valid_0's rmse: 0.161631
# [300]	valid_0's rmse: 0.1616
# [301]	valid_0's rmse: 0.161483
# [302]	valid_0's rmse: 0.161445
# [303]	valid_0's rmse: 0.161389
# [304]	valid_0's rmse: 0.161374
# [305]	valid_0's rmse: 0.161339
# [306]	valid_0's rmse: 0.161309
# [307]	valid_0's rmse: 0.16126
# [308]	valid_0's rmse: 0.161237
# [309]	valid_0's rmse: 0.161208
# [310]	valid_0's rmse: 0.161138
# [311]	valid_0's rmse: 0.161168
# [312]	valid_0's rmse: 0.161139
# [313]	valid_0's rmse: 0.16116
# [314]	valid_0's rmse: 0.161149
# [315]	valid_0's rmse: 0.161019
# [316]	valid_0's rmse: 0.160978
# [317]	valid_0's rmse: 0.160938
# [318]	valid_0's rmse: 0.160894
# [319]	valid_0's rmse: 0.160863
# [320]	valid_0's rmse: 0.160824
# [321]	valid_0's rmse: 0.160766
# [322]	valid_0's rmse: 0.160714
# [323]	valid_0's rmse: 0.160654
# [324]	valid_0's rmse: 0.160622
# [325]	valid_0's rmse: 0.160554
# [326]	valid_0's rmse: 0.160598
# [327]	valid_0's rmse: 0.16055
# [328]	valid_0's rmse: 0.160454
# [329]	valid_0's rmse: 0.160464
# [330]	valid_0's rmse: 0.160475
# [331]	valid_0's rmse: 0.160387
# [332]	valid_0's rmse: 0.160401
# [333]	valid_0's rmse: 0.16022
# [334]	valid_0's rmse: 0.160147
# [335]	valid_0's rmse: 0.160118
# [336]	valid_0's rmse: 0.160025
# [337]	valid_0's rmse: 0.160027
# [338]	valid_0's rmse: 0.160028
# [339]	valid_0's rmse: 0.159956
# [340]	valid_0's rmse: 0.159926
# [341]	valid_0's rmse: 0.159889
# [342]	valid_0's rmse: 0.159854
# [343]	valid_0's rmse: 0.159807
# [344]	valid_0's rmse: 0.159827
# [345]	valid_0's rmse: 0.159812
# [346]	valid_0's rmse: 0.15975
# [347]	valid_0's rmse: 0.159599
# [348]	valid_0's rmse: 0.159551
# [349]	valid_0's rmse: 0.159536
# [350]	valid_0's rmse: 0.159504
# [351]	valid_0's rmse: 0.159469
# [352]	valid_0's rmse: 0.159447
# [353]	valid_0's rmse: 0.159374
# [354]	valid_0's rmse: 0.159328
# [355]	valid_0's rmse: 0.159248
# [356]	valid_0's rmse: 0.159233
# [357]	valid_0's rmse: 0.159175
# [358]	valid_0's rmse: 0.15915
# [359]	valid_0's rmse: 0.159074
# [360]	valid_0's rmse: 0.159027
# [361]	valid_0's rmse: 0.158949
# [362]	valid_0's rmse: 0.15886
# [363]	valid_0's rmse: 0.158834
# [364]	valid_0's rmse: 0.158735
# [365]	valid_0's rmse: 0.158661
# [366]	valid_0's rmse: 0.158661
# [367]	valid_0's rmse: 0.158659
# [368]	valid_0's rmse: 0.158654
# [369]	valid_0's rmse: 0.158654
# [370]	valid_0's rmse: 0.158611
# [371]	valid_0's rmse: 0.158616
# [372]	valid_0's rmse: 0.158585
# [373]	valid_0's rmse: 0.158492
# [374]	valid_0's rmse: 0.158468
# [375]	valid_0's rmse: 0.158433
# [376]	valid_0's rmse: 0.158348
# [377]	valid_0's rmse: 0.158335
# [378]	valid_0's rmse: 0.158276
# [379]	valid_0's rmse: 0.158266
# [380]	valid_0's rmse: 0.158224
# [381]	valid_0's rmse: 0.158124
# [382]	valid_0's rmse: 0.158095
# [383]	valid_0's rmse: 0.158012
# [384]	valid_0's rmse: 0.158021
# [385]	valid_0's rmse: 0.157993
# [386]	valid_0's rmse: 0.157979
# [387]	valid_0's rmse: 0.157934
# [388]	valid_0's rmse: 0.157909
# [389]	valid_0's rmse: 0.157881
# [390]	valid_0's rmse: 0.157805
# [391]	valid_0's rmse: 0.157804
# [392]	valid_0's rmse: 0.157767
# [393]	valid_0's rmse: 0.157764
# [394]	valid_0's rmse: 0.157734
# [395]	valid_0's rmse: 0.157639
# [396]	valid_0's rmse: 0.157606
# [397]	valid_0's rmse: 0.157524
# [398]	valid_0's rmse: 0.157376
# [399]	valid_0's rmse: 0.157353
# [400]	valid_0's rmse: 0.157331
# [401]	valid_0's rmse: 0.157308
# [402]	valid_0's rmse: 0.157233
# [403]	valid_0's rmse: 0.157191
# [404]	valid_0's rmse: 0.157093
# [405]	valid_0's rmse: 0.15712
# [406]	valid_0's rmse: 0.157084
# [407]	valid_0's rmse: 0.157071
# [408]	valid_0's rmse: 0.157028
# [409]	valid_0's rmse: 0.157005
# [410]	valid_0's rmse: 0.156999
# [411]	valid_0's rmse: 0.156955
# [412]	valid_0's rmse: 0.156943
# [413]	valid_0's rmse: 0.156955
# [414]	valid_0's rmse: 0.156898
# [415]	valid_0's rmse: 0.156828
# [416]	valid_0's rmse: 0.156753
# [417]	valid_0's rmse: 0.156734
# [418]	valid_0's rmse: 0.156772
# [419]	valid_0's rmse: 0.156635
# [420]	valid_0's rmse: 0.156605
# [421]	valid_0's rmse: 0.156616
# [422]	valid_0's rmse: 0.156517
# [423]	valid_0's rmse: 0.156512
# [424]	valid_0's rmse: 0.156489
# [425]	valid_0's rmse: 0.156508
# [426]	valid_0's rmse: 0.156493
# [427]	valid_0's rmse: 0.156464
# [428]	valid_0's rmse: 0.156406
# [429]	valid_0's rmse: 0.156431
# [430]	valid_0's rmse: 0.15632
# [431]	valid_0's rmse: 0.156252
# [432]	valid_0's rmse: 0.156173
# [433]	valid_0's rmse: 0.156124
# [434]	valid_0's rmse: 0.15609
# [435]	valid_0's rmse: 0.155971
# [436]	valid_0's rmse: 0.155894
# [437]	valid_0's rmse: 0.155888
# [438]	valid_0's rmse: 0.155871
# [439]	valid_0's rmse: 0.155895
# [440]	valid_0's rmse: 0.155831
# [441]	valid_0's rmse: 0.15584
# [442]	valid_0's rmse: 0.155793
# [443]	valid_0's rmse: 0.155691
# [444]	valid_0's rmse: 0.155616
# [445]	valid_0's rmse: 0.155618
# [446]	valid_0's rmse: 0.155621
# [447]	valid_0's rmse: 0.155578
# [448]	valid_0's rmse: 0.15546
# [449]	valid_0's rmse: 0.155451
# [450]	valid_0's rmse: 0.155409
# [451]	valid_0's rmse: 0.155359
# [452]	valid_0's rmse: 0.155335
# [453]	valid_0's rmse: 0.155292
# [454]	valid_0's rmse: 0.155264
# [455]	valid_0's rmse: 0.15521
# [456]	valid_0's rmse: 0.15514
# [457]	valid_0's rmse: 0.15511
# [458]	valid_0's rmse: 0.155058
# [459]	valid_0's rmse: 0.154975
# [460]	valid_0's rmse: 0.154968
# [461]	valid_0's rmse: 0.154966
# [462]	valid_0's rmse: 0.154908
# [463]	valid_0's rmse: 0.154905
# [464]	valid_0's rmse: 0.154893
# [465]	valid_0's rmse: 0.154863
# [466]	valid_0's rmse: 0.154797
# [467]	valid_0's rmse: 0.154764
# [468]	valid_0's rmse: 0.154724
# [469]	valid_0's rmse: 0.154732
# [470]	valid_0's rmse: 0.154681
# [471]	valid_0's rmse: 0.154653
# [472]	valid_0's rmse: 0.154686
# [473]	valid_0's rmse: 0.154675
# [474]	valid_0's rmse: 0.154612
# [475]	valid_0's rmse: 0.154581
# [476]	valid_0's rmse: 0.154561
# [477]	valid_0's rmse: 0.154558
# [478]	valid_0's rmse: 0.154551
# [479]	valid_0's rmse: 0.154532
# [480]	valid_0's rmse: 0.154544
# [481]	valid_0's rmse: 0.154562
# [482]	valid_0's rmse: 0.154566
# [483]	valid_0's rmse: 0.154497
# [484]	valid_0's rmse: 0.154419
# [485]	valid_0's rmse: 0.154401
# [486]	valid_0's rmse: 0.154303
# [487]	valid_0's rmse: 0.154164
# [488]	valid_0's rmse: 0.154144
# [489]	valid_0's rmse: 0.154138
# [490]	valid_0's rmse: 0.154073
# [491]	valid_0's rmse: 0.154008
# [492]	valid_0's rmse: 0.153992
# [493]	valid_0's rmse: 0.153973
# [494]	valid_0's rmse: 0.153995
# [495]	valid_0's rmse: 0.154009
# [496]	valid_0's rmse: 0.153998
# [497]	valid_0's rmse: 0.153993
# [498]	valid_0's rmse: 0.153902
# [499]	valid_0's rmse: 0.153858
# [500]	valid_0's rmse: 0.153737
# [501]	valid_0's rmse: 0.153697
# [502]	valid_0's rmse: 0.153688
# [503]	valid_0's rmse: 0.153695
# [504]	valid_0's rmse: 0.153678
# [505]	valid_0's rmse: 0.153664
# [506]	valid_0's rmse: 0.153641
# [507]	valid_0's rmse: 0.153648
# [508]	valid_0's rmse: 0.153564
# [509]	valid_0's rmse: 0.153549
# [510]	valid_0's rmse: 0.153471
# [511]	valid_0's rmse: 0.153425
# [512]	valid_0's rmse: 0.153437
# [513]	valid_0's rmse: 0.153366
# [514]	valid_0's rmse: 0.153293
# [515]	valid_0's rmse: 0.15327
# [516]	valid_0's rmse: 0.153219
# [517]	valid_0's rmse: 0.153197
# [518]	valid_0's rmse: 0.153125
# [519]	valid_0's rmse: 0.152975
# [520]	valid_0's rmse: 0.152883
# [521]	valid_0's rmse: 0.15288
# [522]	valid_0's rmse: 0.152863
# [523]	valid_0's rmse: 0.152785
# [524]	valid_0's rmse: 0.152745
# [525]	valid_0's rmse: 0.152729
# [526]	valid_0's rmse: 0.152728
# [527]	valid_0's rmse: 0.152684
# [528]	valid_0's rmse: 0.152679
# [529]	valid_0's rmse: 0.152651
# [530]	valid_0's rmse: 0.152671
# [531]	valid_0's rmse: 0.152645
# [532]	valid_0's rmse: 0.152617
# [533]	valid_0's rmse: 0.152618
# [534]	valid_0's rmse: 0.152597
# [535]	valid_0's rmse: 0.152584
# [536]	valid_0's rmse: 0.152571
# [537]	valid_0's rmse: 0.15257
# [538]	valid_0's rmse: 0.152525
# [539]	valid_0's rmse: 0.152466
# [540]	valid_0's rmse: 0.152448
# [541]	valid_0's rmse: 0.152408
# [542]	valid_0's rmse: 0.152302
# [543]	valid_0's rmse: 0.152257
# [544]	valid_0's rmse: 0.152245
# [545]	valid_0's rmse: 0.152216
# [546]	valid_0's rmse: 0.152191
# [547]	valid_0's rmse: 0.152175
# [548]	valid_0's rmse: 0.152126
# [549]	valid_0's rmse: 0.15197
# [550]	valid_0's rmse: 0.151952
# [551]	valid_0's rmse: 0.15193
# [552]	valid_0's rmse: 0.151939
# [553]	valid_0's rmse: 0.151919
# [554]	valid_0's rmse: 0.151909
# [555]	valid_0's rmse: 0.151772
# [556]	valid_0's rmse: 0.151722
# [557]	valid_0's rmse: 0.151724
# [558]	valid_0's rmse: 0.151724
# [559]	valid_0's rmse: 0.151658
# [560]	valid_0's rmse: 0.151639
# [561]	valid_0's rmse: 0.151638
# [562]	valid_0's rmse: 0.15157
# [563]	valid_0's rmse: 0.151557
# [564]	valid_0's rmse: 0.151495
# [565]	valid_0's rmse: 0.151467
# [566]	valid_0's rmse: 0.151453
# [567]	valid_0's rmse: 0.151437
# [568]	valid_0's rmse: 0.151435
# [569]	valid_0's rmse: 0.151384
# [570]	valid_0's rmse: 0.151285
# [571]	valid_0's rmse: 0.151238
# [572]	valid_0's rmse: 0.151201
# [573]	valid_0's rmse: 0.15119
# [574]	valid_0's rmse: 0.151171
# [575]	valid_0's rmse: 0.151138
# [576]	valid_0's rmse: 0.151099
# [577]	valid_0's rmse: 0.151059
# [578]	valid_0's rmse: 0.15101
# [579]	valid_0's rmse: 0.150998
# [580]	valid_0's rmse: 0.150958
# [581]	valid_0's rmse: 0.150892
# [582]	valid_0's rmse: 0.150818
# [583]	valid_0's rmse: 0.150797
# [584]	valid_0's rmse: 0.150791
# [585]	valid_0's rmse: 0.150729
# [586]	valid_0's rmse: 0.150722
# [587]	valid_0's rmse: 0.15065
# [588]	valid_0's rmse: 0.150578
# [589]	valid_0's rmse: 0.150541
# [590]	valid_0's rmse: 0.150534
# [591]	valid_0's rmse: 0.150531
# [592]	valid_0's rmse: 0.150533
# [593]	valid_0's rmse: 0.150434
# [594]	valid_0's rmse: 0.15039
# [595]	valid_0's rmse: 0.150379
# [596]	valid_0's rmse: 0.150381
# [597]	valid_0's rmse: 0.15036
# [598]	valid_0's rmse: 0.150333
# [599]	valid_0's rmse: 0.15034
# [600]	valid_0's rmse: 0.150342
# [601]	valid_0's rmse: 0.150347
# [602]	valid_0's rmse: 0.150345
# [603]	valid_0's rmse: 0.150319
# [604]	valid_0's rmse: 0.150275
# [605]	valid_0's rmse: 0.15024
# [606]	valid_0's rmse: 0.150242
# [607]	valid_0's rmse: 0.150235
# [608]	valid_0's rmse: 0.15022
# [609]	valid_0's rmse: 0.150224
# [610]	valid_0's rmse: 0.150149
# [611]	valid_0's rmse: 0.150102
# [612]	valid_0's rmse: 0.150101
# [613]	valid_0's rmse: 0.150061
# [614]	valid_0's rmse: 0.150068
# [615]	valid_0's rmse: 0.150054
# [616]	valid_0's rmse: 0.150036
# [617]	valid_0's rmse: 0.150043
# [618]	valid_0's rmse: 0.150015
# [619]	valid_0's rmse: 0.149916
# [620]	valid_0's rmse: 0.149893
# [621]	valid_0's rmse: 0.149855
# [622]	valid_0's rmse: 0.149839
# [623]	valid_0's rmse: 0.149806
# [624]	valid_0's rmse: 0.149788
# [625]	valid_0's rmse: 0.149729
# [626]	valid_0's rmse: 0.149738
# [627]	valid_0's rmse: 0.14972
# [628]	valid_0's rmse: 0.149722
# [629]	valid_0's rmse: 0.149748
# [630]	valid_0's rmse: 0.149612
# [631]	valid_0's rmse: 0.149605
# [632]	valid_0's rmse: 0.149594
# [633]	valid_0's rmse: 0.149602
# [634]	valid_0's rmse: 0.149589
# [635]	valid_0's rmse: 0.14954
# [636]	valid_0's rmse: 0.149449
# [637]	valid_0's rmse: 0.149477
# [638]	valid_0's rmse: 0.14947
# [639]	valid_0's rmse: 0.149454
# [640]	valid_0's rmse: 0.149414
# [641]	valid_0's rmse: 0.149399
# [642]	valid_0's rmse: 0.149418
# [643]	valid_0's rmse: 0.149377
# [644]	valid_0's rmse: 0.149399
# [645]	valid_0's rmse: 0.149398
# [646]	valid_0's rmse: 0.149373
# [647]	valid_0's rmse: 0.149373
# [648]	valid_0's rmse: 0.149333
# [649]	valid_0's rmse: 0.149299
# [650]	valid_0's rmse: 0.149314
# [651]	valid_0's rmse: 0.149282
# [652]	valid_0's rmse: 0.149221
# [653]	valid_0's rmse: 0.149205
# [654]	valid_0's rmse: 0.149235
# [655]	valid_0's rmse: 0.149202
# [656]	valid_0's rmse: 0.149152
# [657]	valid_0's rmse: 0.149136
# [658]	valid_0's rmse: 0.14907
# [659]	valid_0's rmse: 0.149064
# [660]	valid_0's rmse: 0.14907
# [661]	valid_0's rmse: 0.148947
# [662]	valid_0's rmse: 0.14895
# [663]	valid_0's rmse: 0.148931
# [664]	valid_0's rmse: 0.148909
# [665]	valid_0's rmse: 0.148911
# [666]	valid_0's rmse: 0.148889
# [667]	valid_0's rmse: 0.148878
# [668]	valid_0's rmse: 0.148859
# [669]	valid_0's rmse: 0.148791
# [670]	valid_0's rmse: 0.148788
# [671]	valid_0's rmse: 0.1488
# [672]	valid_0's rmse: 0.148805
# [673]	valid_0's rmse: 0.148787
# [674]	valid_0's rmse: 0.148731
# [675]	valid_0's rmse: 0.148636
# [676]	valid_0's rmse: 0.148615
# [677]	valid_0's rmse: 0.148622
# [678]	valid_0's rmse: 0.148603
# [679]	valid_0's rmse: 0.148548
# [680]	valid_0's rmse: 0.148531
# [681]	valid_0's rmse: 0.148424
# [682]	valid_0's rmse: 0.148418
# [683]	valid_0's rmse: 0.148391
# [684]	valid_0's rmse: 0.148374
# [685]	valid_0's rmse: 0.148363
# [686]	valid_0's rmse: 0.148347
# [687]	valid_0's rmse: 0.148314
# [688]	valid_0's rmse: 0.148276
# [689]	valid_0's rmse: 0.148264
# [690]	valid_0's rmse: 0.148264
# [691]	valid_0's rmse: 0.148251
# [692]	valid_0's rmse: 0.148234
# [693]	valid_0's rmse: 0.14821
# [694]	valid_0's rmse: 0.148201
# [695]	valid_0's rmse: 0.148203
# [696]	valid_0's rmse: 0.148187
# [697]	valid_0's rmse: 0.148112
# [698]	valid_0's rmse: 0.147987
# [699]	valid_0's rmse: 0.147897
# [700]	valid_0's rmse: 0.147863
# [701]	valid_0's rmse: 0.147867
# [702]	valid_0's rmse: 0.147842
# [703]	valid_0's rmse: 0.14784
# [704]	valid_0's rmse: 0.147847
# [705]	valid_0's rmse: 0.147787
# [706]	valid_0's rmse: 0.147741
# [707]	valid_0's rmse: 0.147741
# [708]	valid_0's rmse: 0.147733
# [709]	valid_0's rmse: 0.147625
# [710]	valid_0's rmse: 0.147613
# [711]	valid_0's rmse: 0.147601
# [712]	valid_0's rmse: 0.147597
# [713]	valid_0's rmse: 0.147562
# [714]	valid_0's rmse: 0.147506
# [715]	valid_0's rmse: 0.147458
# [716]	valid_0's rmse: 0.14745
# [717]	valid_0's rmse: 0.147388
# [718]	valid_0's rmse: 0.147367
# [719]	valid_0's rmse: 0.147349
# [720]	valid_0's rmse: 0.147288
# [721]	valid_0's rmse: 0.14719
# [722]	valid_0's rmse: 0.147171
# [723]	valid_0's rmse: 0.147169
# [724]	valid_0's rmse: 0.147173
# [725]	valid_0's rmse: 0.147067
# [726]	valid_0's rmse: 0.147058
# [727]	valid_0's rmse: 0.147043
# [728]	valid_0's rmse: 0.147014
# [729]	valid_0's rmse: 0.146968
# [730]	valid_0's rmse: 0.14698
# [731]	valid_0's rmse: 0.146982
# [732]	valid_0's rmse: 0.146975
# [733]	valid_0's rmse: 0.146851
# [734]	valid_0's rmse: 0.146818
# [735]	valid_0's rmse: 0.146759
# [736]	valid_0's rmse: 0.146661
# [737]	valid_0's rmse: 0.146597
# [738]	valid_0's rmse: 0.146582
# [739]	valid_0's rmse: 0.146546
# [740]	valid_0's rmse: 0.1465
# [741]	valid_0's rmse: 0.14647
# [742]	valid_0's rmse: 0.146464
# [743]	valid_0's rmse: 0.146476
# [744]	valid_0's rmse: 0.146457
# [745]	valid_0's rmse: 0.146419
# [746]	valid_0's rmse: 0.146394
# [747]	valid_0's rmse: 0.146343
# [748]	valid_0's rmse: 0.146316
# [749]	valid_0's rmse: 0.146304
# [750]	valid_0's rmse: 0.146237
# [751]	valid_0's rmse: 0.146231
# [752]	valid_0's rmse: 0.146195
# [753]	valid_0's rmse: 0.146208
# [754]	valid_0's rmse: 0.146212
# [755]	valid_0's rmse: 0.146218
# [756]	valid_0's rmse: 0.146221
# [757]	valid_0's rmse: 0.14612
# [758]	valid_0's rmse: 0.146071
# [759]	valid_0's rmse: 0.146031
# [760]	valid_0's rmse: 0.146022
# [761]	valid_0's rmse: 0.14599
# [762]	valid_0's rmse: 0.145961
# [763]	valid_0's rmse: 0.145957
# [764]	valid_0's rmse: 0.145937
# [765]	valid_0's rmse: 0.145925
# [766]	valid_0's rmse: 0.145923
# [767]	valid_0's rmse: 0.145923
# [768]	valid_0's rmse: 0.145905
# [769]	valid_0's rmse: 0.145911
# [770]	valid_0's rmse: 0.1459
# [771]	valid_0's rmse: 0.145873
# [772]	valid_0's rmse: 0.145867
# [773]	valid_0's rmse: 0.145857
# [774]	valid_0's rmse: 0.145839
# [775]	valid_0's rmse: 0.145809
# [776]	valid_0's rmse: 0.145823
# [777]	valid_0's rmse: 0.145801
# [778]	valid_0's rmse: 0.145781
# [779]	valid_0's rmse: 0.145766
# [780]	valid_0's rmse: 0.145722
# [781]	valid_0's rmse: 0.145729
# [782]	valid_0's rmse: 0.145675
# [783]	valid_0's rmse: 0.145643
# [784]	valid_0's rmse: 0.14561
# [785]	valid_0's rmse: 0.145623
# [786]	valid_0's rmse: 0.145611
# [787]	valid_0's rmse: 0.145628
# [788]	valid_0's rmse: 0.145607
# [789]	valid_0's rmse: 0.145587
# [790]	valid_0's rmse: 0.145502
# [791]	valid_0's rmse: 0.145505
# [792]	valid_0's rmse: 0.14545
# [793]	valid_0's rmse: 0.145446
# [794]	valid_0's rmse: 0.145424
# [795]	valid_0's rmse: 0.145393
# [796]	valid_0's rmse: 0.14536
# [797]	valid_0's rmse: 0.145333
# [798]	valid_0's rmse: 0.145292
# [799]	valid_0's rmse: 0.145283
# [800]	valid_0's rmse: 0.145241
# [801]	valid_0's rmse: 0.145183
# [802]	valid_0's rmse: 0.145174
# [803]	valid_0's rmse: 0.145206
# [804]	valid_0's rmse: 0.145169
# [805]	valid_0's rmse: 0.145118
# [806]	valid_0's rmse: 0.145095
# [807]	valid_0's rmse: 0.145047
# [808]	valid_0's rmse: 0.145029
# [809]	valid_0's rmse: 0.145015
# [810]	valid_0's rmse: 0.145008
# [811]	valid_0's rmse: 0.144998
# [812]	valid_0's rmse: 0.145003
# [813]	valid_0's rmse: 0.145012
# [814]	valid_0's rmse: 0.14498
# [815]	valid_0's rmse: 0.144966
# [816]	valid_0's rmse: 0.144981
# [817]	valid_0's rmse: 0.144962
# [818]	valid_0's rmse: 0.144891
# [819]	valid_0's rmse: 0.144845
# [820]	valid_0's rmse: 0.144835
# [821]	valid_0's rmse: 0.14484
# [822]	valid_0's rmse: 0.144827
# [823]	valid_0's rmse: 0.14483
# [824]	valid_0's rmse: 0.144818
# [825]	valid_0's rmse: 0.144821
# [826]	valid_0's rmse: 0.144832
# [827]	valid_0's rmse: 0.144801
# [828]	valid_0's rmse: 0.144795
# [829]	valid_0's rmse: 0.144767
# [830]	valid_0's rmse: 0.144731
# [831]	valid_0's rmse: 0.144619
# [832]	valid_0's rmse: 0.144622
# [833]	valid_0's rmse: 0.144613
# [834]	valid_0's rmse: 0.1446
# [835]	valid_0's rmse: 0.144587
# [836]	valid_0's rmse: 0.144579
# [837]	valid_0's rmse: 0.144568
# [838]	valid_0's rmse: 0.14456
# [839]	valid_0's rmse: 0.144545
# [840]	valid_0's rmse: 0.144559
# [841]	valid_0's rmse: 0.144573
# [842]	valid_0's rmse: 0.144533
# [843]	valid_0's rmse: 0.144545
# [844]	valid_0's rmse: 0.144542
# [845]	valid_0's rmse: 0.144536
# [846]	valid_0's rmse: 0.144535
# [847]	valid_0's rmse: 0.144531
# [848]	valid_0's rmse: 0.144522
# [849]	valid_0's rmse: 0.144497
# [850]	valid_0's rmse: 0.144471
# [851]	valid_0's rmse: 0.144363
# [852]	valid_0's rmse: 0.144251
# [853]	valid_0's rmse: 0.144262
# [854]	valid_0's rmse: 0.144229
# [855]	valid_0's rmse: 0.144215
# [856]	valid_0's rmse: 0.144192
# [857]	valid_0's rmse: 0.1442
# [858]	valid_0's rmse: 0.144181
# [859]	valid_0's rmse: 0.144191
# [860]	valid_0's rmse: 0.144166
# [861]	valid_0's rmse: 0.144144
# [862]	valid_0's rmse: 0.144125
# [863]	valid_0's rmse: 0.144092
# [864]	valid_0's rmse: 0.144055
# [865]	valid_0's rmse: 0.144064
# [866]	valid_0's rmse: 0.143993
# [867]	valid_0's rmse: 0.143981
# [868]	valid_0's rmse: 0.14394
# [869]	valid_0's rmse: 0.143944
# [870]	valid_0's rmse: 0.143933
# [871]	valid_0's rmse: 0.143859
# [872]	valid_0's rmse: 0.143856
# [873]	valid_0's rmse: 0.14386
# [874]	valid_0's rmse: 0.143845
# [875]	valid_0's rmse: 0.143747
# [876]	valid_0's rmse: 0.143721
# [877]	valid_0's rmse: 0.143719
# [878]	valid_0's rmse: 0.143713
# [879]	valid_0's rmse: 0.143725
# [880]	valid_0's rmse: 0.143697
# [881]	valid_0's rmse: 0.1437
# [882]	valid_0's rmse: 0.143694
# [883]	valid_0's rmse: 0.143691
# [884]	valid_0's rmse: 0.14361
# [885]	valid_0's rmse: 0.143611
# [886]	valid_0's rmse: 0.143622
# [887]	valid_0's rmse: 0.143609
# [888]	valid_0's rmse: 0.143599
# [889]	valid_0's rmse: 0.143563
# [890]	valid_0's rmse: 0.143537
# [891]	valid_0's rmse: 0.14354
# [892]	valid_0's rmse: 0.143545
# [893]	valid_0's rmse: 0.143536
# [894]	valid_0's rmse: 0.143443
# [895]	valid_0's rmse: 0.143457
# [896]	valid_0's rmse: 0.143442
# [897]	valid_0's rmse: 0.143473
# [898]	valid_0's rmse: 0.143456
# [899]	valid_0's rmse: 0.143479
# [900]	valid_0's rmse: 0.143459
# [901]	valid_0's rmse: 0.143438
# [902]	valid_0's rmse: 0.143355
# [903]	valid_0's rmse: 0.143349
# [904]	valid_0's rmse: 0.143367
# [905]	valid_0's rmse: 0.143347
# [906]	valid_0's rmse: 0.143242
# [907]	valid_0's rmse: 0.14324
# [908]	valid_0's rmse: 0.143214
# [909]	valid_0's rmse: 0.143163
# [910]	valid_0's rmse: 0.143169
# [911]	valid_0's rmse: 0.143069
# [912]	valid_0's rmse: 0.143078
# [913]	valid_0's rmse: 0.143069
# [914]	valid_0's rmse: 0.143025
# [915]	valid_0's rmse: 0.143041
# [916]	valid_0's rmse: 0.143004
# [917]	valid_0's rmse: 0.142977
# [918]	valid_0's rmse: 0.142928
# [919]	valid_0's rmse: 0.142906
# [920]	valid_0's rmse: 0.142887
# [921]	valid_0's rmse: 0.142894
# [922]	valid_0's rmse: 0.142882
# [923]	valid_0's rmse: 0.142879
# [924]	valid_0's rmse: 0.142893
# [925]	valid_0's rmse: 0.1429
# [926]	valid_0's rmse: 0.142885
# [927]	valid_0's rmse: 0.142866
# [928]	valid_0's rmse: 0.142842
# [929]	valid_0's rmse: 0.142828
# [930]	valid_0's rmse: 0.14283
# [931]	valid_0's rmse: 0.142807
# [932]	valid_0's rmse: 0.142796
# [933]	valid_0's rmse: 0.142741
# [934]	valid_0's rmse: 0.142733
# [935]	valid_0's rmse: 0.142718
# [936]	valid_0's rmse: 0.142726
# [937]	valid_0's rmse: 0.142709
# [938]	valid_0's rmse: 0.142714
# [939]	valid_0's rmse: 0.142629
# [940]	valid_0's rmse: 0.142646
# [941]	valid_0's rmse: 0.142607
# [942]	valid_0's rmse: 0.142588
# [943]	valid_0's rmse: 0.14258
# [944]	valid_0's rmse: 0.142612
# [945]	valid_0's rmse: 0.142598
# [946]	valid_0's rmse: 0.142595
# [947]	valid_0's rmse: 0.142556
# [948]	valid_0's rmse: 0.142539
# [949]	valid_0's rmse: 0.142548
# [950]	valid_0's rmse: 0.142573
# [951]	valid_0's rmse: 0.142495
# [952]	valid_0's rmse: 0.142448
# [953]	valid_0's rmse: 0.142438
# [954]	valid_0's rmse: 0.142436
# [955]	valid_0's rmse: 0.142439
# [956]	valid_0's rmse: 0.14242
# [957]	valid_0's rmse: 0.1424
# [958]	valid_0's rmse: 0.142383
# [959]	valid_0's rmse: 0.142372
# [960]	valid_0's rmse: 0.14237
# [961]	valid_0's rmse: 0.142368
# [962]	valid_0's rmse: 0.14235
# [963]	valid_0's rmse: 0.14232
# [964]	valid_0's rmse: 0.142272
# [965]	valid_0's rmse: 0.142289
# [966]	valid_0's rmse: 0.142229
# [967]	valid_0's rmse: 0.142229
# [968]	valid_0's rmse: 0.142214
# [969]	valid_0's rmse: 0.142199
# [970]	valid_0's rmse: 0.142165
# [971]	valid_0's rmse: 0.142143
# [972]	valid_0's rmse: 0.142126
# [973]	valid_0's rmse: 0.142062
# [974]	valid_0's rmse: 0.142066
# [975]	valid_0's rmse: 0.142071
# [976]	valid_0's rmse: 0.142087
# [977]	valid_0's rmse: 0.142075
# [978]	valid_0's rmse: 0.142073
# [979]	valid_0's rmse: 0.142075
# [980]	valid_0's rmse: 0.142052
# [981]	valid_0's rmse: 0.142034
# [982]	valid_0's rmse: 0.142034
# [983]	valid_0's rmse: 0.142035
# [984]	valid_0's rmse: 0.142024
# [985]	valid_0's rmse: 0.142017
# [986]	valid_0's rmse: 0.141977
# [987]	valid_0's rmse: 0.141968
# [988]	valid_0's rmse: 0.141963
# [989]	valid_0's rmse: 0.141927
# [990]	valid_0's rmse: 0.141895
# [991]	valid_0's rmse: 0.141887
# [992]	valid_0's rmse: 0.141885
# [993]	valid_0's rmse: 0.141837
# [994]	valid_0's rmse: 0.141821
# [995]	valid_0's rmse: 0.141787
# [996]	valid_0's rmse: 0.141719
# [997]	valid_0's rmse: 0.141711
# [998]	valid_0's rmse: 0.141711
# [999]	valid_0's rmse: 0.141679
# [1000]	valid_0's rmse: 0.141689
# Did not meet early stopping. Best iteration is:
# [999]	valid_0's rmse: 0.141679

# %%
prediction = model.predict(x_test)
prediction
# Out:
# ---------------------------------------------------------------------------
# LightGBMError                             Traceback (most recent call last)
# <ipython-input-9-75d4202e7218> in <module>
# ----> 1 prediction = model.predict(x_test)
#       2 prediction
#
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\basic.py in predict(self, data, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, is_reshape, **kwargs)
#    2413         return predictor.predict(data, num_iteration,
#    2414                                  raw_score, pred_leaf, pred_contrib,
# -> 2415                                  data_has_header, is_reshape)
#    2416
#    2417     def refit(self, data, label, decay_rate=0.9, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\basic.py in predict(self, data, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, is_reshape)
#     533             preds, nrow = self.__pred_for_csc(data, num_iteration, predict_type)
#     534         elif isinstance(data, np.ndarray):
# --> 535             preds, nrow = self.__pred_for_np2d(data, num_iteration, predict_type)
#     536         elif isinstance(data, list):
#     537             try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\basic.py in __pred_for_np2d(self, mat, num_iteration, predict_type)
#     621             return preds, nrow
#     622         else:
# --> 623             return inner_predict(mat, num_iteration, predict_type)
#     624
#     625     def __pred_for_csr(self, csr, num_iteration, predict_type):
#
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\basic.py in inner_predict(mat, num_iteration, predict_type, preds)
#     603                 c_str(self.pred_parameter),
#     604                 ctypes.byref(out_num_preds),
# --> 605                 preds.ctypes.data_as(ctypes.POINTER(ctypes.c_double))))
#     606             if n_preds != out_num_preds.value:
#     607                 raise ValueError("Wrong length for predict results")
#
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\basic.py in _safe_call(ret)
#      43     """
#      44     if ret != 0:
# ---> 45         raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
#      46
#      47
#
# LightGBMError: The number of features in data (23) is not the same as it was in training data (24).

# %%
#변수 중요도 파악하기

fig, ax = plt.subplots(figsize=(10,6))
lgb.plot_importance(model, ax=ax)

# %%
# zipcode와 price의 관계

data = pd.concat( [ df['price'], df['zipcode']], axis=1)

f, ax = plt.subplots(figsize=(50,10))
fig = sns.boxplot(data=data, x='zipcode', y='price')

# 98004, 98112 는 집값이 비싼 지역, + 98039, 98040
# 98023, 98108 는 집값이 낮은 지역 + 98106, 98032, 98168

# %%
# zipcode를 쪼개 새로운 feature 만들기

df['zipcode'] = df['zipcode'].astype('str')

df['zipcode-3'] = 'z_' + df['zipcode'].str[2:3] #3번째 글자
df['zipcode-4'] = 'z_' + df['zipcode'].str[3:4] #4번째 글자
df['zipcode-5'] = 'z_' + df['zipcode'].str[4:5] #5번째 글자
df['zipcode-34'] = 'z_' + df['zipcode'].str[2:4] #3~4번째 글자
df['zipcode-45'] = 'z_' + df['zipcode'].str[3:5] #4~5번째 글자
df['zipcode-35'] = 'z_' + df['zipcode'].str[2:3] + df['zipcode'].str[4:5] #3번째, 5번째 글자

df['zipcode'] = 'z_' + df['zipcode']

df

# %%
#zipcode를 위도, 경도로 산점도 나타내기

fig = plt.figure(figsize = (16, 12))

ax1 = plt.subplot(221)
sns.scatterplot(x='long', y='lat', hue='zipcode-3', hue_order=np.sort(df['zipcode-3'].unique()), 
                data=df, ax=ax1)

ax2 = plt.subplot(222)
sns.scatterplot(x='long', y='lat', hue='zipcode-4', hue_order=np.sort(df['zipcode-4'].unique()), 
                data=df, ax=ax2)

ax3 = plt.subplot(223)
sns.scatterplot(x='long', y='lat', hue='zipcode-5', hue_order=np.sort(df['zipcode-5'].unique()), 
                data=df, ax=ax3)

ax4 = plt.subplot(224)
sns.scatterplot(x='long', y='lat', hue='zipcode-34', hue_order=np.sort(df['zipcode-34'].unique()), 
                data=df, ax=ax4)

# %%
fig = plt.figure(figsize = (16, 12))

ax1 = plt.subplot(221)
sns.scatterplot(x='long', y='lat', hue='zipcode-45', hue_order=np.sort(df['zipcode-45'].unique()), 
                data=df, ax=ax1)

ax2 = plt.subplot(222)
sns.scatterplot(x='long', y='lat', hue='zipcode-35', hue_order=np.sort(df['zipcode-35'].unique()), 
                data=df, ax=ax2)

# %%
data = pd.concat( [ df['price'], df['zipcode-35']], axis=1)

f, ax = plt.subplots(figsize=(30,10))
fig = sns.boxplot(data=data, x='zipcode-35', y='price')

#18이 집값이 싼 지역 (3, 5번째 글자)

# %%
data = pd.concat( [ df['price'], df['zipcode-5']], axis=1)

f, ax = plt.subplots(figsize=(30,10))
fig = sns.boxplot(data=data, x='zipcode-5', y='price')

#8이 집값이 싼 지역 (5번째 글자)

# %% [markdown]
# ### PCA Transformation : 차원축소
# 차원축소를 하지 않고 2차원 그대로 PCA transformation 하기

# %%
coord = df[['lat', 'long']]
pca = PCA(n_components = 2)
pca.fit(coord)

coord_pca = pca.transform(coord)

df['coord_pca1'] = coord_pca[:, 0]
df['coord_pca2'] = coord_pca[:, 1] #원본데이터가 변형되어 새로운 feature로 만들어짐. 

sns.scatterplot(x='coord_pca2', y='coord_pca1', hue='price', data=df)

# %%
#test 데이터도 똑같이

coord = df_test[['lat', 'long']]
pca = PCA(n_components = 2)
pca.fit(coord)

coord_pca = pca.transform(coord)

df_test['coord_pca1'] = coord_pca[:, 0]
df_test['coord_pca2'] = coord_pca[:, 1] #원본데이터가 변형되어 새로운 feature로 만들어짐.

df_test['total_rooms'] = df_test['bathrooms'] + df_test['bedrooms']

# %%
df.head()

# %%
# lgb_param 다시 입력 

import lightgbm as lgb

train_ds = lgb.Dataset(x_train, label = y_train)
test_ds = lgb.Dataset(x_test, label = y_test)

params = {
    'objective': 'regression', #method
    'learning_rate': 0.05, #학습률
    'num_leaves': 15,  #하나의 트리가 가질 수 있는 최대 리프 개수
    'bagging_fraction': 0.7, #배깅 사용
    'bagging_freq': 1,
    'feature_fraction': 0.7, #트리를 학습할 때마다 선택하는 feature의 비율
    'seed': random_seed, 
    'metric': ['rmse'], #평가 지표
}

model = lgb.train(params, train_ds, 1000, test_ds, early_stopping_rounds=100)

# %%
fig, ax = plt.subplots(figsize=(10,6))
lgb.plot_importance(model, ax=ax)

# %% [markdown]
# ### Haversine Distance 를 이용한 feature 생성

# %%
def haversine_array(lat1, lng1, lat2, lng2): 
    lat1, lng1, lat2, lng2 = map(np.radians, (lat1, lng1, lat2, lng2)) 
    AVG_EARTH_RADIUS = 6371 # in km 
    lat = lat2 - lat1 
    lng = lng2 - lng1 
    d = np.sin(lat * 0.5) ** 2 + np.cos(lat1) * np.cos(lat2) * np.sin(lng * 0.5) ** 2 
    h = 2 * AVG_EARTH_RADIUS * np.arcsin(np.sqrt(d)) 
    return h

# %%
print(df['lat'].min(), df['lat'].max(), df['long'].min(), df['long'].max())

haversine_dist = haversine_array(df['lat'].min(), df['long'].min(), df['lat'].max(), df['long'].max())
print(f'max distance: {haversine_dist:.2f}km')

# %%
neighbor_df = pd.DataFrame()
lat2 = df['lat'].values
long2 = df['long'].values

lat1 = df.loc[0, 'lat'] # id = 0 house lat
long1 = df.loc[0, 'long'] # id = 0 house long
dist_arr = haversine_array(lat1, long1, lat2, long2)
neighbor_df = pd.DataFrame({
    'id': np.tile(np.array([df.loc[0, 'id']]), df.shape[0]),
    'neighbor_id': df['id'],
    'neighbor_lat': lat2,
    'neighbor_long': long2,
    'distance': dist_arr,
})

print(neighbor_df.shape)
neighbor_df.head()

# %%
df_fin = pd.merge(df, neighbor_df, on='id')

# %%
df_fin.to_csv('df_fin.csv', index=False)
df_fin.head()

# %%
df_fin.shape #피처 총 37개

# %%
df['zipcode-3']

# %%
train_columns = [c for c in df.columns if c not in ['id','price','per_price', 
                                                   'zipcode', 'zipcode-3', 'zipcode-4', 'zipcode-5', 'zipcode-34', 'zipcode-45', 'zipcode-35']]


df_test[train_columns].shape

# %% [markdown]
# ## XGBoost

# %%
import xgboost as xgb

# %%
model_name = "xgboost"

# %%
train_columns = [c for c in df.columns if c not in ['id','price','per_price', 
                                                   'zipcode', 'zipcode-3', 'zipcode-4', 'zipcode-5', 'zipcode-34', 'zipcode-45', 'zipcode-35']]


xgb_params = {
    'eta': 0.01,
    'max_depth': 6,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'objective': 'reg:linear',
    'eval_metric': 'rmse',
    'silent': 1
}

log_target_data = np.log1p(target_data)
print('Transform DMatrix...')

dtrain = xgb.DMatrix(df[train_columns], target_data)
dtest = xgb.DMatrix(df_test[train_columns])

print('Start Cross Validation...')

cv_output = xgb.cv(xgb_params, dtrain, num_boost_round=5000, early_stopping_rounds=50,verbose_eval=500, show_stdv=False)
print('best num_boost_rounds = ', len(cv_output))

rounds = len(cv_output)

model = xgb.train(xgb_params, dtrain, num_boost_round = rounds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-7aa80331d771> in <module>
#      13 }
#      14
# ---> 15 log_target_data = np.log1p(target_data)
#      16 print('Transform DMatrix...')
#      17
#
# NameError: name 'target_data' is not defined

# %%
prediction = np.exp(model.predict(dtest))
submission = pd.DataFrame({
    'Id' : x_test['id'],
    'Price' : prediction
})
submission.to_csv("xgboost.csv",index=False)

# %%
dff = pd.read_csv('xgboost.csv')
dff.head()

# %%
df
